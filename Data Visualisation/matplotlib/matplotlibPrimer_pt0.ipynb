# %% [markdown]
# <a href="https://colab.research.google.com/github/aryamanan/Machiene_Learning/blob/main/matplotlibPrimer_pt0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # matplotlib Primer pt 0

# %%
import matplotlib.pyplot as plt
# OR
from matplotlib import pyplot as plt

# %% [markdown]
# The simplest and most common way to plot a graph using matplotlib is `plt.plot()` method

# %%
plt.plot()
plt.show() # used to show the plot and remove the text clutter

# %% [markdown]
# ##  `plt.subplot()`: matplotlib subplot
# The `plt.subplots()` method takes various arguments, but mostly we supply the following:
#
# - **figsize:** It defines the figure size in inches (takes as tuple), where the first argument is for width and the second argument is for height, i.e., (width, height).
# - **nrows:** It denotes the number of rows for the grid (where we would like to add our plot).
# - **ncols:** It denotes the number of columns for the grid (where we would like to add our plot).

# %%
# Figure and Axes
plt.subplots(figsize=(16,7),nrows=4,ncols=4)
# Out:
# (<Figure size 1600x700 with 16 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %% [markdown]
# Let’s understand the text output, ie
# `(<Figure size 1600x700 with 16 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))`
#
# The text output contains two parts:
#
# - `figure object:` The first part of the text contains the figure object, which shows the Figure size and also a text stating it contains 16 Axes
# - `axes object:` The second part of the text contains an array (list of list) of 16 axes (AxesSubplots), as we requested by supplying the nrows and ncols in subplots( ) method.

# %% [markdown]
# So, now we understand that plt.subplots( ) returns two object
# - (i) figure
# - (ii) axes.
#
# To use them, we can save the returned figure and axes objects to `fig` and `ax` variables.
#
# Note: When you save them to fig and ax, the output still generates the subplots figure as shown below.

# %%
# Saving the returned figure and axes objects

fig,ax=plt.subplots(figsize=(16,7),nrows=4,ncols=4)
# no of plots=nrows x ncols = 4x4=16 and \
# figsize is size of whole
plt.show()

# %% [markdown]
# ## Creating a single blank plot using subplot
#
# - Currently, we will just focus on a single axes object (single plot).
#
# - Let's create a single plot object using subplots( ). To accomplish this, we need to supply the figsize argument, which by default generates a single plot, as shown below.
#
# We will save the returned figure and axes object to fig and ax respectively.

# %%
fig,ax=plt.subplots(figsize=(12,6))

# %% [markdown]
# #### Checking type of figure and axes object

# %%
print(type(fig),"\n",type(ax))
# Out:
# <class 'matplotlib.figure.Figure'>
#  <class 'matplotlib.axes._axes.Axes'>

# %%
# We can also check the default image dpi for the figure\
# object. The matplotlib by default set it to 100 dpi.
fig.dpi
# Out:
# 100.0

# %%
# We can use the fig.axes to identify the object it contains. It is a AxesSubplot object.
fig.axes
# Out:
# [<Axes: >]

# %% [markdown]
# #### Whether fig.axes[0] object is same as ax
#
# Let’s check whether the first element of fig.axes and ax object is same. The output shows True, indicating they are the same.
# Though we can access the axes object from fig, still we will extensively use the saved ax object for generating plots.

# %%
fig.axes[0] is ax
# Out:
# True

# %% [markdown]
# #### Children associated with axes object (ax)
#
# Let’s check what this axes (ax) object contains. We can print its elements using the get_children( ) method.
#
# The axes (ax) object contains the following:
#
# - 4 Spines object (Spines are boundary lines across the plot)
# - 2 axis objects (x and y-axis)
# - Text related to tick labels
# > Ticks are the markers denoting data points, specific values or intervals, used to label the coordinate axes and provide reference points for interpreting the data on the plot.
# - Matplotlib rectangular patch object (irrelevant)

# %%
ax.get_children()
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %% [markdown]
# # Axis Spines
# > Axis spines are the lines confining the plot area. Depending on the situation, we may want to remove some (or all) of them, change their color, make them less visible, regulate their width/style, or change their position. In this article, we'll explore some handy approaches for dealing with axis spines.
#
# We can access the spines using ax.spines, but to get the Spines position we need to iterate through it using a for loop.
# The output shows the four spines are located in the left, right, bottom and top of the plot.

# %%
for s in ax.spines:
    print(s)
# Out:
# left
# right
# bottom
# top

# %% [markdown]
# #### Properties associated with each plot objects
#
# The axes object contains various properties that help in formulating the plot. We can alter these properties as per our requirement to generate the required plot.
#
# For ex--> let’s see what properties the xaxis has. We can apply the properties( ) method on xaxis object to see the associated properties and their default values.

# %%
ax.xaxis.properties()
# Out:
# {'agg_filter': None,
#  'alpha': None,
#  'animated': False,
#  'children': [Text(0.5, 36.72222222222221, ''),
#   Text(1, 38.1111111111111, ''),
# ...
#  'clip_box': <matplotlib.transforms.TransformedBbox at 0x1157631f0>,
#  'clip_on': True,
#  'clip_path': None,
#  'data_interval': array([ inf, -inf]),
#  'figure': <Figure size 1200x600 with 1 Axes>,
#  'gid': None,
#  'gridlines': <a list of 6 Line2D gridline objects>,
#  'in_layout': True,
#  'inverted': False,
#  'label': Text(0.5, 36.72222222222221, ''),
#  'label_position': 'bottom',
#  'label_text': '',
#  'major_formatter': <matplotlib.ticker.ScalarFormatter at 0x11528cc10>,
#  'major_locator': <matplotlib.ticker.AutoLocator at 0x11528c3a0>,
#  'major_ticks': [<matplotlib.axis.XTick at 0x1131bec40>,
# ...
#  'majorticklabels': [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')],
# ...

# %% [markdown]
# > **Note:** We will later see that there are two types of method associated with matplotlib objects. The first type can be used to see the associated values (get methods) and the second type of method (set methods) can be used to alter them.

# %%
from sklearn.datasets import load_iris

# %%
import numpy as np
import pandas as pd

# %%
data=load_iris()
tr=pd.DataFrame(data.target)

# %%
tr.tail(100)
# Out:
#      0
# 50   1
# 51   1
# 52   1
# 53   1
# 54   1
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [100 rows x 1 columns]

# %%
tr.value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# dtype: int64

# %%
df=pd.DataFrame(data.data, columns=data.feature_names)
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(data.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df,tr,random_state=23,test_size=0.2)

# %%
full=pd.concat([df,tr], axis=1)
full.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  0
# 0                5.1               3.5                1.4               0.2  0
# 1                4.9               3.0                1.4               0.2  0
# 2                4.7               3.2                1.3               0.2  0
# 3                4.6               3.1                1.5               0.2  0
# 4                5.0               3.6                1.4               0.2  0

# %%
a=full.columns
print(a)
# Out:
# Index(['sepal length (cm)',  'sepal width (cm)', 'petal length (cm)',
#         'petal width (cm)',                   0],
#       dtype='object')

# %%
a=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'target']
full.columns=a

# %%
full.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
full.drop(full[full["target"]==2].index, inplace=True)

# %%
print(full.head(100))
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     target
# 0        0
# 1        0
# ...

# %%
full["target"].value_counts()
# Out:
# 0    50
# 1    50
# Name: target, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.datasets import make_classification

# %%
lr=LogisticRegression(random_state=21)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import roc_curve, auc

# %%
from sklearn.neural_network import MLPClassifier, MLPRegressor

# %%
dataset=make_classification(n_samples=2000,n_features=20,random_state=42)

# %%
print(dataset[0])
# Out:
# [[ 0.23146158 -0.64163877  1.16226111 ... -0.74936149 -1.4072111
#    3.94233101]
#  [ 0.52297157  0.59113158 -0.95870373 ...  1.47650002  1.87357639
#    1.82096723]
#  [-0.1319809   2.9354067  -1.63343741 ...  2.86591955  0.92764949
#    0.98390616]
#  ...
#  [ 0.22584183 -0.9804655  -0.6211348  ... -1.00172913  0.33512613
#   -0.94296337]
#  [ 2.24618801 -1.61200268 -0.83026215 ... -1.25288106 -0.78682763
#   -1.85757145]
#  [ 0.65468849 -0.46981517 -0.91232551 ... -0.78568795  1.51539675
#   -0.46249915]]

# %%
a=["f"+str(i) for i in range(1,21)]
print(a)
# Out:
# ['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20']

# %%
df=pd.DataFrame(dataset[0], columns=['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20'])

# %%
df.head()
# Out:
#          f1        f2        f3        f4        f5        f6        f7  \
# 0  0.231462 -0.641639  1.162261 -0.571047  0.062669 -1.932734  2.047652
# 1  0.522972  0.591132 -0.958704  0.148943 -0.772951 -1.339270 -0.336320
# 2 -0.131981  2.935407 -1.633437  0.957263  0.224883  1.651234  1.409745
# 3  0.631804 -1.764013  1.203177 -0.011081 -2.360726 -0.953579  1.002952
# 4  1.475454 -1.977694 -1.159536  0.027177 -0.601656 -0.334773 -0.621332
#
#          f8        f9       f10       f11       f12       f13       f14  \
# 0 -0.249918 -1.353783  0.567940 -0.034313  0.423080  0.309730 -0.318567
# 1 -1.516858 -0.934485 -0.392974 -0.082838  0.204989 -0.071514 -0.893419
# 2  3.038282  0.284965 -2.691420 -0.233843  1.047855  0.162444  0.117998
# 3 -0.708234 -0.160513  2.022730 -0.879129 -0.499515  1.312825 -0.878339
# 4 -0.696117 -0.370513  1.895294  0.824702  0.012654 -1.446757 -0.148429
#
#         f15       f16       f17       f18       f19       f20
# ...

# %%
X=df[['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19']]
y=df[['f20']]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=43,test_size=0.2)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df["f20"])
plt.show()

# %%
np.median(df["f20"])
# Out:
# -0.011254873184902722

# %%
df.loc[df["f20"]<-0.011,"f20"]=0
df.loc[df["f20"]!=0,"f20"]=1

# %%
df["f20"].value_counts()
# Out:
# 1.0    1000
# 0.0    1000
# Name: f20, dtype: int64

# %%
df.head(100)
# Out:
#           f1        f2        f3        f4        f5        f6        f7  \
# 0   0.231462 -0.641639  1.162261 -0.571047  0.062669 -1.932734  2.047652
# 1   0.522972  0.591132 -0.958704  0.148943 -0.772951 -1.339270 -0.336320
# 2  -0.131981  2.935407 -1.633437  0.957263  0.224883  1.651234  1.409745
# 3   0.631804 -1.764013  1.203177 -0.011081 -2.360726 -0.953579  1.002952
# 4   1.475454 -1.977694 -1.159536  0.027177 -0.601656 -0.334773 -0.621332
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.346213  2.887313 -0.742780 -0.912242  2.803996 -0.883406  0.806412
# 96  0.025882  0.745228  0.472768  1.442657 -0.653760  0.246457  0.955967
# 97  0.336171 -0.176786 -2.504467  0.828058 -1.294090  0.237438 -1.575577
# 98 -0.125819  1.140320 -0.153501 -0.069852  0.660741 -0.848905 -0.797485
# 99  0.261625 -0.900098  0.870818  0.374908 -0.004578 -0.054255 -1.280612
#
#           f8        f9       f10       f11       f12       f13       f14  \
# ...

# %%
X=df.drop(df["f20"])
y=df.f20

# %%
X_train,X_test,y_test,y_train=train_test_split(X,y,random_state=32,test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-31f17991aaa2> in <cell line: 1>()
# ----> 1 X_train,X_test,y_test,y_train=train_test_split(X,y,random_state=32,test_size=0.2)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2557         raise ValueError("At least one array required as input")
#    2558
# -> 2559     arrays = indexable(*arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     441
#     442     result = [_make_indexable(X) for X in iterables]
# --> 443     check_consistent_length(*result)
#     444     return result
#     445
#
# ...

# %%
print(X.shape, y.shape)
# Out:
# (1998, 20) (2000,)

# %%
df.iloc[23]
# Out:
# f1    -0.733425
# f2    -0.320554
# f3     0.681661
# f4    -0.620264
# f5     0.352743
# f6    -0.770227
# f7     0.293747
# f8     0.543524
# f9     0.326596
# f10    0.225193
# f11   -0.244400
# f12    0.243103
# f13   -0.011006
# f14   -1.398098
# f15    1.125680
# f16    0.555858
# f17   -0.513313
# f18   -0.727674
# f19    0.783731
# f20    1.000000
# Name: 23, dtype: float64

# %%
print(X.shape,y.shape)
# Out:
# (1998, 20) (2000,)

# %%
y=y[:X.shape[0]]

# %%
print(X.shape,y.shape)
# Out:
# (1998, 20) (1998,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=21)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (1598, 20) (400, 20) (1598,) (400,)

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import recall_score, precision_score, accuracy_score

# %%
from sklearn.metrics import f1_score, roc_curve, roc_auc_score, auc

# %%
pre=precision_score(y_pred,y_test)
print(pre)
# Out:
# 0.5297029702970297

# %%
acc=accuracy_score(y_pred,y_test)
senstivity=recall_score(y_pred,y_test)
print(acc, senstivity)
# Out:
# 0.5225 0.5270935960591133

# %%
tpr, fpr, threshold=roc_curve(y_pred,y_test)

# %%
print(tpr[1], fpr[1], threshold[1])
# Out:
# 0.48223350253807107 0.5270935960591133 1.0
